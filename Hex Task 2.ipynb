# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#import data set
df = pd.read_csv('movie_metadata.csv')
df.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  ...  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi  ...
# ...

# %%
#display last row
df.tail()
# Out:
#       color     director_name  num_critic_for_reviews  duration  \
# 5038  Color       Scott Smith                     1.0      87.0
# 5039  Color               NaN                    43.0      43.0
# 5040  Color  Benjamin Roberds                    13.0      76.0
# 5041  Color       Daniel Hsia                    14.0     100.0
# 5042  Color          Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 5038                      2.0                   318.0     Daphne Zuniga
# 5039                      NaN                   319.0     Valorie Curry
# 5040                      0.0                     0.0     Maxwell Moody
# 5041                      0.0                   489.0     Daniel Henney
# 5042                     16.0                    16.0  Brian Herzlinger
#
#       actor_1_facebook_likes    gross                        genres  ...  \
# ...

# %%
#Shape of dataset
df.shape
# Out:
# (5043, 28)

# %%
print("Number of rows",df.shape[0])
print("Number of Columns",df.shape[1])
# Out:
# Number of rows 5043
# Number of Columns 28

# %%
#Dataset information
df.info(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5043 entries, 0 to 5042
# Data columns (total 28 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   color                      5024 non-null   object
#  1   director_name              4939 non-null   object
#  2   num_critic_for_reviews     4993 non-null   float64
#  3   duration                   5028 non-null   float64
#  4   director_facebook_likes    4939 non-null   float64
#  5   actor_3_facebook_likes     5020 non-null   float64
#  6   actor_2_name               5030 non-null   object
#  7   actor_1_facebook_likes     5036 non-null   float64
#  8   gross                      4159 non-null   float64
#  9   genres                     5043 non-null   object
#  10  actor_1_name               5036 non-null   object
#  11  movie_title                5043 non-null   object
#  12  num_voted_users            5043 non-null   int64
# ...

# %%
#Missing values 
print('Any missing values?',df.isnull().values.any())
# Out:
# Any missing values? True

# %%
df.isnull().sum()
# Out:
# color                         19
# director_name                104
# num_critic_for_reviews        50
# duration                      15
# director_facebook_likes      104
# actor_3_facebook_likes        23
# actor_2_name                  13
# actor_1_facebook_likes         7
# gross                        884
# genres                         0
# actor_1_name                   7
# movie_title                    0
# num_voted_users                0
# cast_total_facebook_likes      0
# actor_3_name                  23
# facenumber_in_poster          13
# plot_keywords                153
# movie_imdb_link                0
# num_user_for_reviews          21
# language                      14
# country                        5
# content_rating               303
# budget                       492
# title_year                   108
# actor_2_facebook_likes        13
# imdb_score                     0
# aspect_ratio                 329
# movie_facebook_likes           0
# dtype: int64

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
per_missing = df.isnull().sum()*100/len(df)
per_missing
# Out:
# color                         0.376760
# director_name                 2.062265
# num_critic_for_reviews        0.991473
# duration                      0.297442
# director_facebook_likes       2.062265
# actor_3_facebook_likes        0.456078
# actor_2_name                  0.257783
# actor_1_facebook_likes        0.138806
# gross                        17.529248
# genres                        0.000000
# actor_1_name                  0.138806
# movie_title                   0.000000
# num_voted_users               0.000000
# cast_total_facebook_likes     0.000000
# actor_3_name                  0.456078
# facenumber_in_poster          0.257783
# plot_keywords                 3.033908
# movie_imdb_link               0.000000
# num_user_for_reviews          0.416419
# language                      0.277613
# country                       0.099147
# content_rating                6.008328
# budget                        9.756098
# title_year                    2.141582
# ...

# %%
#remove missing values
df.dropna(axis=0)
# Out:
#       color      director_name  num_critic_for_reviews  duration  \
# 0     Color      James Cameron                   723.0     178.0
# 1     Color     Gore Verbinski                   302.0     169.0
# 2     Color         Sam Mendes                   602.0     148.0
# 3     Color  Christopher Nolan                   813.0     164.0
# 5     Color     Andrew Stanton                   462.0     132.0
# ...     ...                ...                     ...       ...
# 5026  Color    Olivier Assayas                    81.0     110.0
# 5027  Color       Jafar Panahi                    64.0      90.0
# 5033  Color      Shane Carruth                   143.0      77.0
# 5035  Color   Robert Rodriguez                    56.0      81.0
# 5042  Color           Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes       actor_2_name  \
# 0                         0.0                   855.0   Joel David Moore
# ...

# %%
#checking for duplicate
dup_df=df.duplicated().any()
print("Are there any duplicate values?",dup_df)
# Out:
# Are there any duplicate values? True

# %%
#drop duplicates
df=df.drop_duplicates()
df
# Out:
#       color      director_name  num_critic_for_reviews  duration  \
# 0     Color      James Cameron                   723.0     178.0
# 1     Color     Gore Verbinski                   302.0     169.0
# 2     Color         Sam Mendes                   602.0     148.0
# 3     Color  Christopher Nolan                   813.0     164.0
# 4       NaN        Doug Walker                     NaN       NaN
# ...     ...                ...                     ...       ...
# 5038  Color        Scott Smith                     1.0      87.0
# 5039  Color                NaN                    43.0      43.0
# 5040  Color   Benjamin Roberds                    13.0      76.0
# 5041  Color        Daniel Hsia                    14.0     100.0
# 5042  Color           Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                         0.0                   855.0  Joel David Moore
# ...

# %%
#Overall Statistics
df.describe()
# Out:
#        num_critic_for_reviews     duration  director_facebook_likes  \
# count             4949.000000  4983.000000              4895.000000
# mean               139.890079   107.213325               688.679060
# std                121.477586    25.248775              2821.649616
# min                  1.000000     7.000000                 0.000000
# 25%                 50.000000    93.000000                 7.000000
# 50%                110.000000   103.000000                49.000000
# 75%                195.000000   118.000000               192.000000
# max                813.000000   511.000000             23000.000000
#
#        actor_3_facebook_likes  actor_1_facebook_likes         gross  \
# count             4975.000000             4991.000000  4.124000e+03
# mean               639.900905             6556.939892  4.832565e+07
# std               1643.298282            15061.586700  6.796483e+07
# min                  0.000000                0.000000  1.620000e+02
# ...

# %%
df.columns
# Out:
# Index(['color', 'director_name', 'num_critic_for_reviews', 'duration',
#        'director_facebook_likes', 'actor_3_facebook_likes', 'actor_2_name',
#        'actor_1_facebook_likes', 'gross', 'genres', 'actor_1_name',
#        'movie_title', 'num_voted_users', 'cast_total_facebook_likes',
#        'actor_3_name', 'facenumber_in_poster', 'plot_keywords',
#        'movie_imdb_link', 'num_user_for_reviews', 'language', 'country',
#        'content_rating', 'budget', 'title_year', 'actor_2_facebook_likes',
#        'imdb_score', 'aspect_ratio', 'movie_facebook_likes'],
#       dtype='object')

# %%
#display Title of the moving duration
df[df['duration']>=180]['movie_title']
# Out:
# 10       Batman v Superman: Dawn of Justice
# 23      The Hobbit: The Desolation of Smaug
# 25                                King Kong
# 26                                  Titanic
# 32                               Iron Man 3
#                         ...
# 4077                  Judgment at Nuremberg
# 4087         Deadline Gallipoli
# 4694                              King Kong
# 4708                              Woodstock
# 4747                          Seven Samurai
# Name: movie_title, Length: 68, dtype: object

# %%
#Which year There was Highest Average Voting
df.columns
# Out:
# Index(['color', 'director_name', 'num_critic_for_reviews', 'duration',
#        'director_facebook_likes', 'actor_3_facebook_likes', 'actor_2_name',
#        'actor_1_facebook_likes', 'gross', 'genres', 'actor_1_name',
#        'movie_title', 'num_voted_users', 'cast_total_facebook_likes',
#        'actor_3_name', 'facenumber_in_poster', 'plot_keywords',
#        'movie_imdb_link', 'num_user_for_reviews', 'language', 'country',
#        'content_rating', 'budget', 'title_year', 'actor_2_facebook_likes',
#        'imdb_score', 'aspect_ratio', 'movie_facebook_likes'],
#       dtype='object')

# %%
df.groupby('title_year')['num_voted_users'].mean().sort_values(ascending=False)
# Out:
# title_year
# 1957.0    298614.500000
# 1975.0    269305.500000
# 1942.0    240866.500000
# 1939.0    194869.000000
# 1960.0    179921.666667
#               ...
# 1932.0      3519.000000
# 1950.0      3167.000000
# 1943.0      1553.000000
# 1944.0      1079.000000
# 1920.0         5.000000
# Name: num_voted_users, Length: 91, dtype: float64

# %%
plt.figure(figsize=(70, 70))
sns.barplot(x='title_year',y='num_voted_users',data=df)
plt.title("Votes By Year")
plt.xticks(rotation=45,fontsize=10)
plt.yticks(fontsize=10)
plt.xlabel('Year', fontsize=12)
plt.show()

# %%
#Average rating for each director
df.columns
# Out:
# Index(['color', 'director_name', 'num_critic_for_reviews', 'duration',
#        'director_facebook_likes', 'actor_3_facebook_likes', 'actor_2_name',
#        'actor_1_facebook_likes', 'gross', 'genres', 'actor_1_name',
#        'movie_title', 'num_voted_users', 'cast_total_facebook_likes',
#        'actor_3_name', 'facenumber_in_poster', 'plot_keywords',
#        'movie_imdb_link', 'num_user_for_reviews', 'language', 'country',
#        'content_rating', 'budget', 'title_year', 'actor_2_facebook_likes',
#        'imdb_score', 'aspect_ratio', 'movie_facebook_likes'],
#       dtype='object')

# %%
df.groupby('director_name')['imdb_score'].mean().sort_values(ascending=False)
# Out:
# director_name
# John Blanchard        9.5
# Mitchell Altieri      8.7
# Sadyk Sher-Niyaz      8.7
# Cary Bell             8.7
# Mike Mayhall          8.6
#                      ...
# Georgia Hilton        2.2
# Vondie Curtis-Hall    2.1
# Frédéric Auburtin     2.0
# A. Raven Cruz         1.9
# Lawrence Kasanoff     1.7
# Name: imdb_score, Length: 2398, dtype: float64

# %%
#Display Top 10 Lengthy Movies
df.columns
# Out:
# Index(['color', 'director_name', 'num_critic_for_reviews', 'duration',
#        'director_facebook_likes', 'actor_3_facebook_likes', 'actor_2_name',
#        'actor_1_facebook_likes', 'gross', 'genres', 'actor_1_name',
#        'movie_title', 'num_voted_users', 'cast_total_facebook_likes',
#        'actor_3_name', 'facenumber_in_poster', 'plot_keywords',
#        'movie_imdb_link', 'num_user_for_reviews', 'language', 'country',
#        'content_rating', 'budget', 'title_year', 'actor_2_facebook_likes',
#        'imdb_score', 'aspect_ratio', 'movie_facebook_likes'],
#       dtype='object')

# %%
top10_len=df.nlargest(10,'duration')[['movie_title','duration']].set_index('movie_title')

# %%
top10_len
# Out:
#                            duration
# movie_title
# Trapped                       511.0
# Carlos                        334.0
# Blood In, Blood Out           330.0
# Heaven's Gate                 325.0
# The Legend of Suriyothai      300.0
# Das Boot                      293.0
# Apocalypse Now                289.0
# The Company                   286.0
# Gods and Generals             280.0
# Gettysburg                    271.0

# %%
sns.barplot(x='duration',y=top10_len.index,data=top10_len)
# Out:
# <Axes: xlabel='duration', ylabel='movie_title'>

# %%
#Display number of Movies Per year
df.columns
# Out:
# Index(['color', 'director_name', 'num_critic_for_reviews', 'duration',
#        'director_facebook_likes', 'actor_3_facebook_likes', 'actor_2_name',
#        'actor_1_facebook_likes', 'gross', 'genres', 'actor_1_name',
#        'movie_title', 'num_voted_users', 'cast_total_facebook_likes',
#        'actor_3_name', 'facenumber_in_poster', 'plot_keywords',
#        'movie_imdb_link', 'num_user_for_reviews', 'language', 'country',
#        'content_rating', 'budget', 'title_year', 'actor_2_facebook_likes',
#        'imdb_score', 'aspect_ratio', 'movie_facebook_likes'],
#       dtype='object')

# %%
df['title_year'].value_counts()
# Out:
# title_year
# 2009.0    258
# 2014.0    248
# 2006.0    238
# 2013.0    236
# 2010.0    229
#          ...
# 1932.0      1
# 1916.0      1
# 1934.0      1
# 1925.0      1
# 1920.0      1
# Name: count, Length: 91, dtype: int64

# %%
plt.figure(figsize=(70, 70))  # Wider figure to fit all years
sns.countplot(x='title_year', data=df, order=sorted(df['title_year'].dropna().unique()))
plt.xticks(rotation=45, fontsize=30)
plt.xlabel("Year", fontsize=30)
plt.ylabel("Movie Count", fontsize=30)
plt.title("Number of Movies per Year", fontsize=30)
plt.tight_layout()
plt.show()

# %%
#Find most popular movie Title
df[df['gross'].max()==df['gross']]['movie_title']
# Out:
# 0    Avatar
# Name: movie_title, dtype: object

# %%
df.columns
# Out:
# Index(['color', 'director_name', 'num_critic_for_reviews', 'duration',
#        'director_facebook_likes', 'actor_3_facebook_likes', 'actor_2_name',
#        'actor_1_facebook_likes', 'gross', 'genres', 'actor_1_name',
#        'movie_title', 'num_voted_users', 'cast_total_facebook_likes',
#        'actor_3_name', 'facenumber_in_poster', 'plot_keywords',
#        'movie_imdb_link', 'num_user_for_reviews', 'language', 'country',
#        'content_rating', 'budget', 'title_year', 'actor_2_facebook_likes',
#        'imdb_score', 'aspect_ratio', 'movie_facebook_likes'],
#       dtype='object')

# %%
#Display Top 10 highest rated movie Titles and its Directors
top10_len=df.nlargest(10,'imdb_score')[['movie_title','director_name','imdb_score']]\.set_index('movie_title')

# %%
top10_len
# Out:
#                                                        director_name  \
# movie_title
# Towering Inferno                                      John Blanchard
# The Shawshank Redemption                              Frank Darabont
# The Godfather                                   Francis Ford Coppola
# Dekalog                                                          NaN
# Dekalog                                                          NaN
# Kickboxer: Vengeance                                  John Stockwell
# The Dark Knight                                    Christopher Nolan
# The Godfather: Part II                          Francis Ford Coppola
# Fargo                                                            NaN
# The Lord of the Rings: The Return of the King          Peter Jackson
#
#                                                 imdb_score
# movie_title
# Towering Inferno                                       9.5
# The Shawshank Redemption                               9.3
# ...

# %%
sns.barplot(x='imdb_score',y=top10_len.index,data=top10_len,hue='director_name',dodge=False)
plt.legend(bbox_to_anchor=(1.05,1),loc=2)

# %%
#Display Top 10 Highest Gross movie title
df.columns
# Out:
# Index(['color', 'director_name', 'num_critic_for_reviews', 'duration',
#        'director_facebook_likes', 'actor_3_facebook_likes', 'actor_2_name',
#        'actor_1_facebook_likes', 'gross', 'genres', 'actor_1_name',
#        'movie_title', 'num_voted_users', 'cast_total_facebook_likes',
#        'actor_3_name', 'facenumber_in_poster', 'plot_keywords',
#        'movie_imdb_link', 'num_user_for_reviews', 'language', 'country',
#        'content_rating', 'budget', 'title_year', 'actor_2_facebook_likes',
#        'imdb_score', 'aspect_ratio', 'movie_facebook_likes'],
#       dtype='object')

# %%
df.nlargest(10,'gross')['movie_title']
# Out:
# 0                                          Avatar
# 26                                        Titanic
# 29                                 Jurassic World
# 17                                   The Avengers
# 66                                The Dark Knight
# 240     Star Wars: Episode I - The Phantom Menace
# 3024           Star Wars: Episode IV - A New Hope
# 8                         Avengers: Age of Ultron
# 3                           The Dark Knight Rises
# 582                                       Shrek 2
# Name: movie_title, dtype: object

# %%
top_10=df.nlargest(10,'gross')[['movie_title','gross']].set_index('movie_title')

# %%
top_10
# Out:
#                                                   gross
# movie_title
# Avatar                                      760505847.0
# Titanic                                     658672302.0
# Jurassic World                              652177271.0
# The Avengers                                623279547.0
# The Dark Knight                             533316061.0
# Star Wars: Episode I - The Phantom Menace   474544677.0
# Star Wars: Episode IV - A New Hope          460935665.0
# Avengers: Age of Ultron                     458991599.0
# The Dark Knight Rises                       448130642.0
# Shrek 2                                     436471036.0

# %%
sns.barplot(x='gross',y=top_10.index,data=top_10)
plt.title("Top 10 Gross Movie Titles")
plt.show()

# %%
#Find Average rating of Movies
df.columns
# Out:
# Index(['color', 'director_name', 'num_critic_for_reviews', 'duration',
#        'director_facebook_likes', 'actor_3_facebook_likes', 'actor_2_name',
#        'actor_1_facebook_likes', 'gross', 'genres', 'actor_1_name',
#        'movie_title', 'num_voted_users', 'cast_total_facebook_likes',
#        'actor_3_name', 'facenumber_in_poster', 'plot_keywords',
#        'movie_imdb_link', 'num_user_for_reviews', 'language', 'country',
#        'content_rating', 'budget', 'title_year', 'actor_2_facebook_likes',
#        'imdb_score', 'aspect_ratio', 'movie_facebook_likes'],
#       dtype='object')

# %%
df.groupby('movie_title')['gross'].mean().sort_values(ascending=False)
# Out:
# movie_title
# Avatar              760505847.0
# Titanic             658672302.0
# Jurassic World      652177271.0
# The Avengers        623279547.0
# The Dark Knight     533316061.0
#                        ...
# Zambezia                    NaN
# Zipper                      NaN
# Zombie Hunter               NaN
# Zulu                        NaN
# [Rec]                       NaN
# Name: gross, Length: 4917, dtype: float64

# %%
sns.scatterplot(x="imdb_score",y="gross",data=df)
# Out:
# <Axes: xlabel='imdb_score', ylabel='gross'>

# %%
#Clssify movies based on Ratings 
df.columns
# Out:
# Index(['color', 'director_name', 'num_critic_for_reviews', 'duration',
#        'director_facebook_likes', 'actor_3_facebook_likes', 'actor_2_name',
#        'actor_1_facebook_likes', 'gross', 'genres', 'actor_1_name',
#        'movie_title', 'num_voted_users', 'cast_total_facebook_likes',
#        'actor_3_name', 'facenumber_in_poster', 'plot_keywords',
#        'movie_imdb_link', 'num_user_for_reviews', 'language', 'country',
#        'content_rating', 'budget', 'title_year', 'actor_2_facebook_likes',
#        'imdb_score', 'aspect_ratio', 'movie_facebook_likes'],
#       dtype='object')

# %%
def imdb_score_rating(imdb_score):
    if imdb_score >= 7.0:
        return "Excellent"
    elif imdb_score >= 6.0:
        return "Good"
    else:
        return "Average"

# %%
    df['rating'] = df['imdb_score'].apply(imdb_score_rating)

# %%
df.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  ...  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi  ...
# ...

# %%
df.columns
# Out:
# Index(['color', 'director_name', 'num_critic_for_reviews', 'duration',
#        'director_facebook_likes', 'actor_3_facebook_likes', 'actor_2_name',
#        'actor_1_facebook_likes', 'gross', 'genres', 'actor_1_name',
#        'movie_title', 'num_voted_users', 'cast_total_facebook_likes',
#        'actor_3_name', 'facenumber_in_poster', 'plot_keywords',
#        'movie_imdb_link', 'num_user_for_reviews', 'language', 'country',
#        'content_rating', 'budget', 'title_year', 'actor_2_facebook_likes',
#        'imdb_score', 'aspect_ratio', 'movie_facebook_likes', 'rating'],
#       dtype='object')

# %%
#Number of Action movies
df['genres'].dtype
# Out:
# dtype('O')

# %%
len(df['genres'].str.contains('Action',case=False))
# Out:
# 4998

# %%
#Unique Values from Genre
df['genres']
# Out:
# 0       Action|Adventure|Fantasy|Sci-Fi
# 1              Action|Adventure|Fantasy
# 2             Action|Adventure|Thriller
# 3                       Action|Thriller
# 4                           Documentary
#                      ...
# 5038                       Comedy|Drama
# 5039       Crime|Drama|Mystery|Thriller
# 5040              Drama|Horror|Thriller
# 5041               Comedy|Drama|Romance
# 5042                        Documentary
# Name: genres, Length: 4998, dtype: object

# %%
list1=[]
for value in df['genres']:
    list1.append(value.split(','))

# %%
list1
# Out:
# [['Action|Adventure|Fantasy|Sci-Fi'],
#  ['Action|Adventure|Fantasy'],
#  ['Action|Adventure|Thriller'],
#  ['Action|Thriller'],
#  ['Documentary'],
#  ['Action|Adventure|Sci-Fi'],
#  ['Action|Adventure|Romance'],
#  ['Adventure|Animation|Comedy|Family|Fantasy|Musical|Romance'],
#  ['Action|Adventure|Sci-Fi'],
#  ['Adventure|Family|Fantasy|Mystery'],
#  ['Action|Adventure|Sci-Fi'],
#  ['Action|Adventure|Sci-Fi'],
#  ['Action|Adventure'],
#  ['Action|Adventure|Fantasy'],
#  ['Action|Adventure|Western'],
#  ['Action|Adventure|Fantasy|Sci-Fi'],
#  ['Action|Adventure|Family|Fantasy'],
#  ['Action|Adventure|Sci-Fi'],
#  ['Action|Adventure|Fantasy'],
#  ['Action|Adventure|Comedy|Family|Fantasy|Sci-Fi'],
#  ['Adventure|Fantasy'],
#  ['Action|Adventure|Fantasy'],
#  ['Action|Adventure|Drama|History'],
#  ['Adventure|Fantasy'],
#  ['Adventure|Family|Fantasy'],
#  ['Action|Adventure|Drama|Romance'],
#  ['Drama|Romance'],
#  ['Action|Adventure|Sci-Fi'],
#  ['Action|Adventure|Sci-Fi|Thriller'],
# ...

# %%
one_d=[]
for item in list1:
    for item1 in item:
       one_d.append(item1)

# %%
one_d
# Out:
# ['Action|Adventure|Fantasy|Sci-Fi',
#  'Action|Adventure|Fantasy',
#  'Action|Adventure|Thriller',
#  'Action|Thriller',
#  'Documentary',
#  'Action|Adventure|Sci-Fi',
#  'Action|Adventure|Romance',
#  'Adventure|Animation|Comedy|Family|Fantasy|Musical|Romance',
#  'Action|Adventure|Sci-Fi',
#  'Adventure|Family|Fantasy|Mystery',
#  'Action|Adventure|Sci-Fi',
#  'Action|Adventure|Sci-Fi',
#  'Action|Adventure',
#  'Action|Adventure|Fantasy',
#  'Action|Adventure|Western',
#  'Action|Adventure|Fantasy|Sci-Fi',
#  'Action|Adventure|Family|Fantasy',
#  'Action|Adventure|Sci-Fi',
#  'Action|Adventure|Fantasy',
#  'Action|Adventure|Comedy|Family|Fantasy|Sci-Fi',
#  'Adventure|Fantasy',
#  'Action|Adventure|Fantasy',
#  'Action|Adventure|Drama|History',
#  'Adventure|Fantasy',
#  'Adventure|Family|Fantasy',
#  'Action|Adventure|Drama|Romance',
#  'Drama|Romance',
#  'Action|Adventure|Sci-Fi',
#  'Action|Adventure|Sci-Fi|Thriller',
#  'Action|Adventure|Sci-Fi|Thriller',
# ...

# %%
uni_list = []
for item in one_d:
    if item not in uni_list:
        uni_list.append(item)

# %%
len(uni_list)
# Out:
# 914

# %%
uni_list
# Out:
# ['Action|Adventure|Fantasy|Sci-Fi',
#  'Action|Adventure|Fantasy',
#  'Action|Adventure|Thriller',
#  'Action|Thriller',
#  'Documentary',
#  'Action|Adventure|Sci-Fi',
#  'Action|Adventure|Romance',
#  'Adventure|Animation|Comedy|Family|Fantasy|Musical|Romance',
#  'Adventure|Family|Fantasy|Mystery',
#  'Action|Adventure',
#  'Action|Adventure|Western',
#  'Action|Adventure|Family|Fantasy',
#  'Action|Adventure|Comedy|Family|Fantasy|Sci-Fi',
#  'Adventure|Fantasy',
#  'Action|Adventure|Drama|History',
#  'Adventure|Family|Fantasy',
#  'Action|Adventure|Drama|Romance',
#  'Drama|Romance',
#  'Action|Adventure|Sci-Fi|Thriller',
#  'Action|Adventure|Fantasy|Romance',
#  'Action|Adventure|Fantasy|Sci-Fi|Thriller',
#  'Adventure|Animation|Comedy|Family|Fantasy',
#  'Adventure|Animation|Comedy|Family|Sport',
#  'Action|Crime|Thriller',
#  'Action|Adventure|Horror|Sci-Fi|Thriller',
#  'Adventure|Animation|Family|Sci-Fi',
#  'Action|Comedy|Crime|Thriller',
# ...

# %%
#No of films of each Genre were made
one_d=[]
for item in list1:
    for item1 in item:
       one_d.append(item1)

# %%
one_d
# Out:
# ['Action|Adventure|Fantasy|Sci-Fi',
#  'Action|Adventure|Fantasy',
#  'Action|Adventure|Thriller',
#  'Action|Thriller',
#  'Documentary',
#  'Action|Adventure|Sci-Fi',
#  'Action|Adventure|Romance',
#  'Adventure|Animation|Comedy|Family|Fantasy|Musical|Romance',
#  'Action|Adventure|Sci-Fi',
#  'Adventure|Family|Fantasy|Mystery',
#  'Action|Adventure|Sci-Fi',
#  'Action|Adventure|Sci-Fi',
#  'Action|Adventure',
#  'Action|Adventure|Fantasy',
#  'Action|Adventure|Western',
#  'Action|Adventure|Fantasy|Sci-Fi',
#  'Action|Adventure|Family|Fantasy',
#  'Action|Adventure|Sci-Fi',
#  'Action|Adventure|Fantasy',
#  'Action|Adventure|Comedy|Family|Fantasy|Sci-Fi',
#  'Adventure|Fantasy',
#  'Action|Adventure|Fantasy',
#  'Action|Adventure|Drama|History',
#  'Adventure|Fantasy',
#  'Adventure|Family|Fantasy',
#  'Action|Adventure|Drama|Romance',
#  'Drama|Romance',
#  'Action|Adventure|Sci-Fi',
#  'Action|Adventure|Sci-Fi|Thriller',
#  'Action|Adventure|Sci-Fi|Thriller',
# ...

# %%
from collections import Counter

# %%
Counter(one_d)
# Out:
# Counter({'Drama': 235,
#          'Comedy': 205,
#          'Comedy|Drama': 189,
#          'Comedy|Drama|Romance': 187,
#          'Comedy|Romance': 158,
#          'Drama|Romance': 151,
#          'Crime|Drama|Thriller': 100,
#          'Horror': 70,
#          'Action|Crime|Drama|Thriller': 67,
#          'Action|Crime|Thriller': 64,
#          'Drama|Thriller': 64,
#          'Crime|Drama': 63,
#          'Crime|Drama|Mystery|Thriller': 54,
#          'Horror|Thriller': 54,
#          'Documentary': 51,
#          'Action|Adventure|Sci-Fi': 49,
#          'Comedy|Crime': 49,
#          'Action|Adventure|Thriller': 46,
#          'Drama|Mystery|Thriller': 37,
#          'Action|Adventure|Sci-Fi|Thriller': 35,
#          'Biography|Drama': 35,
#          'Horror|Mystery|Thriller': 33,
#          'Action|Adventure|Fantasy': 30,
#          'Action|Thriller': 30,
#          'Action|Comedy|Crime': 30,
#          'Adventure|Animation|Comedy|Family|Fantasy': 29,
# ...
